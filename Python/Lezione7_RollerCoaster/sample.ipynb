# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('data/coaster_db.csv')

# %% [markdown]
# # Analisi del frame #

# %%
print("Dimensione del database", df.shape)
print("Tipi delle colonne presenti\n", df.dtypes)
# Out:
# Dimensione del database (1087, 56)
# Tipi delle colonne presenti
#  coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# Fast Lane available               object
# Replaced                          object
# Track layout                      object
# Fastrack available                object
# Soft opening date.1               object
# Closing date                      object
# Opened                            object
# Replaced by                       object
# Website                           object
# Flash Pass Available              object
# Must transfer from wheelchair     object
# Theme                             object
# Single rider line available       object
# Restraint Style                   object
# Flash Pass available              object
# Acceleration                      object
# Restraints                        object
# Name                              object
# year_introduced                    int64
# latitude                         float64
# longitude                        float64
# Type_Main                         object
# opening_date_clean                object
# speed1                            object
# speed2                            object
# speed1_value                     float64
# speed1_unit                       object
# speed_mph                        float64
# height_value                     float64
# height_unit                       object
# height_ft                        float64
# Inversions_clean                   int64
# Gforce_clean                     float64
# dtype: object

# %% [markdown]
# # Visualizzazione dei dati #

# %%
df['coaster_name'].head(10)
# Out:
# 0                        Switchback Railway
# 1                         Flip Flap Railway
# 2    Switchback Railway (Euclid Beach Park)
# 3              Loop the Loop (Coney Island)
# 4              Loop the Loop (Young's Pier)
# 5                            Cannon Coaster
# 6                             Leap-The-Dips
# 7          Figure Eight (Euclid Beach Park)
# 8                              Drop the Dip
# 9        Scenic Railway (Euclid Beach Park)
# Name: coaster_name, dtype: object

# %%
df.loc[0]
# Out:
# coaster_name                            Switchback Railway
# Length                                      600 ft (180 m)
# Speed                                     6 mph (9.7 km/h)
# Location                                      Coney Island
# Status                                             Removed
# Opening date                                 June 16, 1884
# Type                                                  Wood
# Manufacturer                        LaMarcus Adna Thompson
# Height restriction                                     NaN
# Model                                          Lift Packed
# Height                                        50 ft (15 m)
# Inversions                                             NaN
# Lift/launch system                                 gravity
# Cost                                                   NaN
# Trains                                                 NaN
# Park section                     Coney Island Cyclone Site
# Duration                                              1:00
# Capacity                              1600 riders per hour
# G-force                                                2.9
# Designer                            LaMarcus Adna Thompson
# Max vertical angle                                     30°
# Drop                                          43 ft (13 m)
# Soft opening date                                      NaN
# Fast Lane available                                    NaN
# Replaced                                               NaN
# Track layout                        Gravity pulled coaster
# Fastrack available                                     NaN
# Soft opening date.1                                    NaN
# Closing date                                           NaN
# Opened                                                 NaN
# Replaced by                                            NaN
# Website                                                NaN
# Flash Pass Available                                   NaN
# Must transfer from wheelchair                          NaN
# Theme                                                  NaN
# Single rider line available                            NaN
# Restraint Style                                        NaN
# Flash Pass available                                   NaN
# Acceleration                                           NaN
# Restraints                                             NaN
# Name                                                   NaN
# year_introduced                                       1884
# latitude                                            40.574
# longitude                                          -73.978
# Type_Main                                             Wood
# opening_date_clean                              1884-06-16
# speed1                                              6 mph
# speed2                                            9.7 km/h
# speed1_value                                           6.0
# speed1_unit                                            mph
# speed_mph                                              6.0
# height_value                                          50.0
# height_unit                                             ft
# height_ft                                              NaN
# Inversions_clean                                         0
# Gforce_clean                                           2.9
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df['Speed'].describe()
# Out:
# count                  937
# unique                 243
# top       50 mph (80 km/h)
# freq                    63
# Name: Speed, dtype: object

# %%
df['Opening Date']=pd.to_datetime(df['Opening date'],
 errors='coerce', format='%Y').fillna(
 pd.to_datetime(df['Opening date'],
 errors='coerce')
)
df[['coaster_name','Opening date' ]].head()
# Out:
#                              coaster_name   Opening date
# 0                      Switchback Railway  June 16, 1884
# 1                       Flip Flap Railway           1895
# 2  Switchback Railway (Euclid Beach Park)            NaN
# 3            Loop the Loop (Coney Island)           1901
# 4            Loop the Loop (Young's Pier)           1901

# %%
df.loc[~df['speed1_value'].isna()]
# Out:
#                         coaster_name                Length  Speed  \
# 0                 Switchback Railway        600 ft (180 m)    NaN
# 6                      Leap-The-Dips      1,452 ft (443 m)    NaN
# 12       Backety-Back Scenic Railway                   NaN    NaN
# 13       Racer (1910 roller coaster)    4,500 ft (1,400 m)    NaN
# 15          The Great Scenic Railway      967 m (3,173 ft)    NaN
# ...                              ...                   ...    ...
# 1082         American Dreier Looping    3,444 ft (1,050 m)    NaN
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)    NaN
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)    NaN
# 1085                         Tumbili        770 ft (230 m)    NaN
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)    NaN
#
#                         Location              Status   Opening date  \
# 0                   Coney Island             Removed  June 16, 1884
# 6                  Lakemont Park           Operating           1902
# 12                 Crystal Beach             Removed           1909
# 13                     Kennywood           Operating           1927
# 15           Luna Park Melbourne           Operating  December 1912
# ...                          ...                 ...            ...
# 1082                       Other                 NaN            NaN
# 1083  Busch Gardens Williamsburg  Under construction           2022
# 1084                       Other                 NaN  June 16, 2016
# 1085              Kings Dominion  Under construction            NaN
# 1086    Six Flags Magic Mountain  Under construction           2022
#
#                                       Type                  Manufacturer  \
# 0                                     Wood        LaMarcus Adna Thompson
# 6                     Wood – Side friction  Federal Construction Company
# 12                          Wood – Shuttle                           NaN
# 13                           Wood – Racing                  Charlie Mach
# 15                                    Wood             LaMarcus Thompson
# ...                                    ...                           ...
# 1082                                 Steel             Anton Schwarzkopf
# 1083                      Steel – Launched                       Intamin
# 1084                      Steel – Launched                        Vekoma
# 1085  Steel – 4th Dimension – Wing Coaster     S&S – Sansei Technologies
# 1086                   Steel – Single-rail   Rocky Mountain Construction
#
#       Height restriction                     Model  ...     speed2  \
# 0                    NaN               Lift Packed  ...   9.7 km/h
# 6                    NaN                       NaN  ...    16 km/h
# 12                   NaN                       NaN  ...    16 km/h
# 13        46 in (117 cm)                    Racing  ...    64 km/h
# 15    100 cm (3 ft 3 in)                       NaN  ...     37 mph
# ...                  ...                       ...  ...        ...
# 1082      55 in (140 cm)                       NaN  ...    85 km/h
# 1083                 NaN             Blitz Coaster  ...   117 km/h
# 1084    4[2] ft (122 cm)  Motorbike roller coaster  ...  95.4 km/h
# 1085                 NaN              4D Free Spin  ...    55 km/h
# 1086                 NaN           Raptor – Custom  ...    93 km/h
#
#       speed1_value speed1_unit speed_mph height_value height_unit height_ft  \
# 0              6.0         mph       6.0         50.0          ft       NaN
# 6             10.0         mph      10.0         41.0          ft       NaN
# 12            10.0         mph      10.0          NaN         NaN       NaN
# 13            40.0         mph      40.0         72.5          ft       NaN
# 15            60.0        km/h      37.3         16.0           m      52.5
# ...            ...         ...       ...          ...         ...       ...
# 1082          53.0         mph      53.0        111.0          ft       NaN
# 1083          73.0         mph      73.0        178.0          ft       NaN
# 1084          59.3         mph      59.3         78.1          ft       NaN
# 1085          34.0         mph      34.0        112.0          ft       NaN
# 1086          58.0         mph      58.0        131.0          ft       NaN
#
#      Inversions_clean Gforce_clean Opening Date
# 0                   0          2.9   1884-06-16
# 6                   0          NaN   1902-01-01
# 12                  0          NaN   1909-01-01
# 13                  0          NaN   1927-01-01
# 15                  0          NaN          NaT
# ...               ...          ...          ...
# 1082                3          4.7          NaT
# 1083                2          NaN   2022-01-01
# 1084                0          4.0   2016-06-16
# 1085                0          NaN          NaT
# 1086                3          NaN   2022-01-01
#
# [937 rows x 57 columns]
